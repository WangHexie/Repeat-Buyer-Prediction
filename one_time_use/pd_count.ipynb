# %%
import numpy as np
from basic_function import *

# %%
a = get_train_log(None)

# %%
u = get_user_info()

# %%
u
# Out:
#         user_id  age_range  gender
# 0        376517          6       1
# 1        234512          5       0
# 2        344532          5       0
# 3        186135          5       0
# 4         30230          5       0
# 5        272389          6       1
# 6        281071          4       0
# 7        139859          7       0
# 8        198411          5       1
# 9         67037          4       1
# 10       149002          5       2
# 11         7468          4       0
# 12        94292          4       0
# 13       347414          6       1
# 14       191719          4       0
# 15       391524          5       1
# 16       153790          6       0
# 17       349112          3       1
# 18       344766          6       0
# 19        81816          5       0
# 20       307304          5       0
# 21        78617          4       1
# 22       234232          5       0
# 23        57005          4       1
# 24       284893          6       1
# 25       366342          4       0
# ...

# %%
a = a[a["action_type"] == 2]

# %%
p = a.groupby(by="user_id").size().reset_index()
p.columns=["user_id","count"]

# %%
p.describe()
# Out:
#              user_id          count
# count  424170.000000  424170.000000
# mean   212085.500000       7.761379
# std    122447.476179       7.916426
# min         1.000000       1.000000
# 25%    106043.250000       3.000000
# 50%    212085.500000       5.000000
# 75%    318127.750000      10.000000
# max    424170.000000     905.000000

# %%
p.sort_values(by=["count"], axis=0)
# Out:
#         user_id  count
# 424169   424170      1
# 340491   340492      1
# 340481   340482      1
# 96666     96667      1
# 340471   340472      1
# 96680     96681      1
# 340470   340471      1
# 340463   340464      1
# 96695     96696      1
# 96696     96697      1
# 340461   340462      1
# 96703     96704      1
# 96730     96731      1
# 340493   340494      1
# 96731     96732      1
# 96747     96748      1
# 340417   340418      1
# 96750     96751      1
# 96755     96756      1
# 96764     96765      1
# 340404   340405      1
# 340391   340392      1
# 96776     96777      1
# 96778     96779      1
# 340389   340390      1
# 96791     96792      1
# 96804     96805      1
# 96742     96743      1
# 340496   340497      1
# 340498   340499      1
# ...         ...    ...
# 46981     46982    149
# 249459   249460    152
# 56175     56176    152
# 132508   132509    152
# 88255     88256    154
# 93954     93955    157
# 185185   185186    160
# 159358   159359    162
# ...

# %%
p[p["count"] < 4].describe()
# Out:
#              user_id          count
# count  132651.000000  132651.000000
# mean   211726.333899       2.081386
# std    122573.819599       0.794598
# min         4.000000       1.000000
# 25%    105562.500000       1.000000
# 50%    211431.000000       2.000000
# 75%    318101.500000       3.000000
# max    424170.000000       3.000000

# %%
a.to_pickle("pic.pkl",compression="zip")

# %%
u.to_pickle("user_info.pkl",compression="zip")
