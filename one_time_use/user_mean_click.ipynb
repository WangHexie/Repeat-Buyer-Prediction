# %%
# %matplotlib inline

import numpy as np
from basic_function import *

# %%
a = get_train_log(None)

# %%
a = a[a["action_type"] == 2]

# %%
p = a.groupby(by="user_id").size().reset_index()
p.columns=["user_id","count"]

# %%
p["count"].plot.kde(ind=np.array(range(2,5002,50)))

# %%
id = p[p["count"]<2000]

# %%
id
# Out:
#         user_id  count
# 0             1     33
# 1             2     63
# 2             3     68
# 3             4     50
# 4             5    173
# 5             6    249
# 6             7     14
# 7             8     91
# 8             9     87
# 9            10     64
# 10           11     32
# 11           12     67
# 12           13     21
# 13           14   1034
# 14           15    148
# 15           16     67
# 16           17     40
# 17           18    110
# 18           19    114
# 19           20    162
# 20           21    620
# 21           22    471
# 22           23    174
# 23           24     61
# 24           25    118
# 25           26     56
# 26           27     62
# 27           28    594
# 28           29     64
# 29           30     14
# ...         ...    ...
# 424140   424141     54
# 424141   424142     86
# 424142   424143     42
# 424143   424144     30
# 424144   424145    203
# 424145   424146     53
# 424146   424147     49
# 424147   424148     88
# 424148   424149    151
# 424149   424150     34
# 424150   424151    141
# 424151   424152     26
# 424152   424153    119
# 424153   424154     36
# 424154   424155     34
# 424155   424156    635
# 424156   424157     12
# 424157   424158     52
# 424158   424159     14
# 424159   424160     23
# 424160   424161     81
# 424161   424162    258
# 424162   424163    140
# 424163   424164    135
# 424164   424165     24
# 424165   424166     90
# 424166   424167     35
# 424167   424168    223
# 424168   424169    297
# 424169   424170     40
#
# [423760 rows x 2 columns]

# %%
p[p["user_id"].isin(id)]
# Out:
# Empty DataFrame
# Columns: [user_id, count]
# Index: []

# %%
p.describe(percentiles=[.99,.999,.9999,.99999,.999999])
# Out:
# count       424170.000000
# mean           129.488955
# std            187.738160
# min              2.000000
# 50%             74.000000
# 99%            865.000000
# 99.9%         1977.000000
# 99.99%        3756.498600
# 99.999%       7945.895900
# 99.9999%     13360.070572
# max          14468.000000
# Name: count, dtype: float64

# %%
p.sort_values(by=["count"], axis=0)
# Out:
#         user_id  count
# 424169   424170      1
# 340491   340492      1
# 340481   340482      1
# 96666     96667      1
# 340471   340472      1
# 96680     96681      1
# 340470   340471      1
# 340463   340464      1
# 96695     96696      1
# 96696     96697      1
# 340461   340462      1
# 96703     96704      1
# 96730     96731      1
# 340493   340494      1
# 96731     96732      1
# 96747     96748      1
# 340417   340418      1
# 96750     96751      1
# 96755     96756      1
# 96764     96765      1
# 340404   340405      1
# 340391   340392      1
# 96776     96777      1
# 96778     96779      1
# 340389   340390      1
# 96791     96792      1
# 96804     96805      1
# 96742     96743      1
# 340496   340497      1
# 340498   340499      1
# ...         ...    ...
# 46981     46982    149
# 249459   249460    152
# 56175     56176    152
# 132508   132509    152
# 88255     88256    154
# 93954     93955    157
# 185185   185186    160
# 159358   159359    162
# 262122   262123    162
# 310090   310091    167
# 172976   172977    171
# 257309   257310    181
# 282195   282196    181
# 168788   168789    190
# 193932   193933    195
# 287160   287161    195
# 261853   261854    198
# 321650   321651    210
# 286948   286949    224
# 237235   237236    230
# 212440   212441    236
# 68321     68322    253
# 122848   122849    274
# 404460   404461    275
# 55304     55305    280
# 278594   278595    298
# 153822   153823    357
# 77456     77457    365
# 265989   265990    563
# 382315   382316    905
#
# [424170 rows x 2 columns]

# %%
p[p["count"] < 4].describe()
# Out:
#              user_id          count
# count  132651.000000  132651.000000
# mean   211726.333899       2.081386
# std    122573.819599       0.794598
# min         4.000000       1.000000
# 25%    105562.500000       1.000000
# 50%    211431.000000       2.000000
# 75%    318101.500000       3.000000
# max    424170.000000       3.000000

# %%
a.to_pickle("pic.pkl",compression="zip")

# %%
u.to_pickle("user_info.pkl",compression="zip")
